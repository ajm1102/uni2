# %%
import pandas as pd
import datetime
from datetime import time
import matplotlib.pyplot as plt
import seaborn as sns
df_accidents = pd.read_csv('dft-road-casualty-statistics-accident-2019.csv', low_memory=False)
df_casualty = pd.read_csv('dft-road-casualty-statistics-casualty-2019.csv', low_memory=False)
df_vehicle = pd.read_csv('dft-road-casualty-statistics-vehicle-2019.csv', low_memory=False)



df_accidents['datetime'] = df_accidents['date'] + ' ' + df_accidents['time']

df_accidents['datetime'] = pd.to_datetime(df_accidents['datetime'], infer_datetime_format=True)

df_accidents = df_accidents.sort_values('datetime')
df_accidents = df_accidents.set_index(pd.DatetimeIndex(df_accidents['datetime']))

# %%
hours = df_accidents.groupby([df_accidents['datetime'].dt.hour]).count()
plt.bar(hours['accident_index'].index, hours['accident_index'].values)
plt.show()

# %%
hours = df_accidents.groupby([df_accidents['datetime'].dt.weekday]).count()
plt.bar(hours['accident_index'].index, hours['accident_index'].values)
plt.show()

# %%
import geopy.distance

coords_1 = (52.2296756, 21.0122287)
coords_2 = (52.406374, 16.9251681)

print(geopy.distance.geodesic(coords_1, coords_2).km)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [69], in <cell line: 1>()
# ----> 1 import geopy.distance
#       3 coords_1 = (52.2296756, 21.0122287)
#       4 coords_2 = (52.406374, 16.9251681)
#
# ModuleNotFoundError: No module named 'geopy'

# %%
df_accidents.loc['2019-02-24']
# Out:
#                     accident_index  accident_year accident_reference  \
# datetime
# 2019-02-24 00:01:00  201997GP01202           2019          97GP01202
# 2019-02-24 00:02:00  2019450818264           2019          450818264
# 2019-02-24 00:04:00  2019551900207           2019          551900207
# 2019-02-24 00:11:00  2019420818209           2019          420818209
# 2019-02-24 00:15:00  2019010165246           2019          010165246
# ...                            ...            ...                ...
# 2019-02-24 23:30:00  2019010165385           2019          010165385
# 2019-02-24 23:30:00  2019010170225           2019          010170225
# 2019-02-24 23:36:00  2019530819089           2019          530819089
# 2019-02-24 23:54:00  2019040831103           2019          040831103
# 2019-02-24 23:59:00  2019160818279           2019          160818279
#
#                      location_easting_osgr  location_northing_osgr  longitude  \
# datetime
# ...

# %%
# Out:
#                     accident_index  accident_year accident_reference  \
# datetime
# 2019-01-01 00:06:00  2019320634369           2019          320634369
# 2019-01-01 00:20:00  2019010155220           2019          010155220
# 2019-01-01 00:28:00  2019350810982           2019          350810982
# 2019-01-01 00:30:00  2019230353185           2019          230353185
# 2019-01-01 00:34:00  2019070000684           2019          070000684
# ...                            ...            ...                ...
# 2019-12-31 23:42:00  2019980938595           2019          980938595
# 2019-12-31 23:45:00  2019010228016           2019          010228016
# 2019-12-31 23:45:00  2019420914629           2019          420914629
# 2019-12-31 23:50:00  2019010228000           2019          010228000
# 2019-12-31 23:53:00  2019200923613           2019          200923613
#
#                      location_easting_osgr  location_northing_osgr  longitude  \
# datetime
# ...
